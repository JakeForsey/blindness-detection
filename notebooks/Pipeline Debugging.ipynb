# %%
import sys
# Jupyter notebook setup

# Add our code
sys.path.append("../")

# Make sure imports are updated constantly
# %load_ext autoreload
# %autoreload 2

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
from src.preprocess.pipeline import Pipeline
from src.preprocess.pipeline import Pipeline
from src.data.dataset import APTOSSubmissionDataset

# %%
DATA_FRAME = "../data/aptos2019-blindness-detection/test.csv"
DATA_DIRECTORY = "../data/aptos2019-blindness-detection/test_images"

# Pipeline to debug
PIPELINE_STAGES = [
    (
        "crop_dark_borders",
        {
            "tol": 10,
        },
    ),
    (
        "normalize_left_right",
        {},
    ),
]

# %%
df = pd.read_csv(DATA_FRAME)

pipeline = Pipeline(PIPELINE_STAGES, debug=True)
dataset = APTOSSubmissionDataset(df, DATA_DIRECTORY, pipeline)

# %%
plt.figure(figsize=(40, 40))
image = dataset[1]
